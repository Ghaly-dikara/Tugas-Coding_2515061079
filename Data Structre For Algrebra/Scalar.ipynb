# %% [markdown]
# ###Scalar

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 7

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 9

# %%
# tampilkan tipe data dari y
type (y)
# Out:
# int

# %%
# jumlahkan x+y
x + y
# Out:
# 16

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 0.79

# %%
# jumlahkan x_float dengan y
x_float + y
# Out:
# 9.79

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# ###Tensorflow

# %%
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow
import tensorflow as tf

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_tf = tf.Variable(7)

# %%
# tampilkan tipe data dari x
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=7>

# %%
type(x_tf)
# Out:
# tensorflow.python.ops.resource_variable_ops.ResourceVariable

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_tf = tf.Variable(9)

# %%
# tampilkan tipe data dari y
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=9>

# %%
type(y_tf)
# Out:
# tensorflow.python.ops.resource_variable_ops.ResourceVariable

# %%
# jumlahkan x+y
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=16>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=16>

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
tf_x_float = tf.Variable(0.79)

# %%
# jumlahkan x_float dengan y
result = tf_x_float + tf.cast(y_tf, tf.float32)
print(result)
# Out:
# tf.Tensor(9.79, shape=(), dtype=float32)

# %%
# tampilkan tipe data dari x_float
tf_x_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.7900000214576721>

# %% [markdown]
# ###Torch

# %%
# lakukan tahapan pada soal 1 dengan menggunakan pytorch
import torch

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_pt = torch.tensor(7)

# %%
# tampilkan tipe data dari x
x_pt.shape
# Out:
# torch.Size([])

# %%
type(x_pt)
# Out:
# torch.Tensor

# %%
x_pt.size
# Out:
# <function Tensor.size>

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_pt = torch.tensor(9)

# %%
# tampilkan tipe data dari y
y_pt.shape
# Out:
# torch.Size([])

# %%
type(y_pt)
# Out:
# torch.Tensor

# %%
y_pt.size
# Out:
# <function Tensor.size>

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_pt = torch.tensor(0.79)
x_float_pt
# Out:
# tensor(0.7900)

# %%
# jumlahkan x_float dengan y
x_float_pt + y_pt
# Out:
# tensor(9.7900)

# %%
# tampilkan tipe data dari x_float
x_float_pt.shape
# Out:
# torch.Size([])

# %%
type(x_float_pt)
# Out:
# torch.Tensor

# %%
x_float_pt.size
# Out:
# <function Tensor.size>
