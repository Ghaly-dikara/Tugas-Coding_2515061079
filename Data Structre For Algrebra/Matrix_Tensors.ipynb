# %% [markdown]
# ###Matrix Tensors

# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[70,90],[97,79],[70,90]])
X
# Out:
# array([[70, 90],
#        [97, 79],
#        [70, 90]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (3, 2)

# %%
X.size
# Out:
# 6

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X [:,0]
# Out:
# array([70, 97, 70])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X [1,:]
# Out:
# array([97, 79])

# %% [markdown]
# ### Pytorch

# %%
import torch
import tensorflow as tf

# %%
X_pt = torch.tensor([[70,90],[79,97],[90,70]])
X_pt
# Out:
# tensor([[70, 90],
#         [79, 97],
#         [90, 70]])

# %%
# tampilkan ukuran dari matrix X
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
X_pt.size
# Out:
# <function Tensor.size>

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X_pt [:,0]
# Out:
# tensor([70, 79, 90])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X_pt [1,:]
# Out:
# tensor([79, 97])

# %% [markdown]
# ### Tensorflow

# %%
X_tf = tf.Variable([[70,90],[79,97],[90,70]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[70, 90],
#        [79, 97],
#        [90, 70]], dtype=int32)>

# %%
# tampilkan ukuran dari matrix X
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X_tf [:,0]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([70, 79, 90], dtype=int32)>

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X_tf [1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([79, 97], dtype=int32)>
